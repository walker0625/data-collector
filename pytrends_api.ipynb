# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

keyword1 = "서울페이"
period = "today 5-y"

trend_obj = TrendReq()
trend_obj.build_payload(kw_list=[keyword1], timeframe=period, geo="KR")
trend_df = trend_obj.interest_over_time()

plt.rc('font', family='NanumGothic')
plt.style.use("ggplot")
plt.figure(figsize=(14,5))

trend_df[keyword1].plot()

plt.title("서울페이 지난 5년간 검색 트렌드 수", size=15)
plt.legend(loc="best")
plt.show()
# Out:
# c:\walker\code\data-collector\.venv\Lib\site-packages\pytrends\request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
